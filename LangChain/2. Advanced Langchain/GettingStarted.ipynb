# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# profile={'max_input_tokens': 128000, 'max_output_tokens': 16384, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x0000023A0F4EB390> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000023A0F4EB750> root_client=<openai.OpenAI object at 0x0000023A0F4EB110> root_async_client=<openai.AsyncOpenAI object at 0x0000023A0F4EB4D0> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********') stream_usage=True

# %%
## Input and get response from the LLM

result = llm.invoke("What is esports? How is it in India?")

# %%
print(result)
# Out:
# content='Esports, short for electronic sports, is a form of competition using video games. It often takes the form of organized, multiplayer video game competitions, particularly between professional players, individually or as teams. Esports spans various game genres, including first-person shooters (FPS), multiplayer online battle arenas (MOBA), real-time strategy (RTS), and fighting games, among others. Popular esports titles include "League of Legends," "Dota 2," "Counter-Strike: Global Offensive," "Overwatch," and "Fortnite."\n\nEsports has become a major global industry, complete with players, teams, leagues, sponsors, streaming platforms, tournaments, and even dedicated esports venues. It\'s notable for its large audiences, both in-person at live events and online via streaming platforms like Twitch and YouTube Gaming.\n\n### Esports in India\n\nEsports has been growing steadily in India, thanks to the increasing penetration of internet services, affordable gaming hardware, an
# ...

# %% [markdown]
# # ChatPromptTemplate

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an expert AI Engineer. Provide me answers based on the questions."),
    ("user", "{input}")
])

# %%
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on the questions.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain = prompt | llm

response = chain.invoke({"input": "Can you tell me about Esports in India, specifically Valorant? Do you know about Excali - Karan Mhaswadkar?"})
print(response)
# Out:
# content='Esports has been rapidly growing in India, with games like "Valorant" becoming particularly popular. "Valorant," a tactical first-person shooter developed by Riot Games, has gained a significant following in India due to its competitive gameplay and strategic depth. The Indian esports scene for "Valorant" consists of numerous teams and players, competitive tournaments, and a growing fanbase. This growth is supported by a combination of improved internet infrastructure, increased accessibility to gaming, and investments from both local and international entities into esports organizations.\n\nKaran "Excali" Mhaswadkar is a notable figure in the Indian "Valorant" esports scene. He is a professional esports player known for his skills in "Valorant." Excali gained recognition for his performance in various national and international competitions. As a player, he has been associated with several Indian esports teams and has played an important role in raising the profile of India
# ...

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
## String Output Parser

from langchain_core.output_parsers import StrOutputParser

# %%
output_parser = StrOutputParser()
chain = prompt | llm | output_parser

response = chain.invoke({"input": "Can you tell me about Esports in India, specifically Valorant? Do you know about Excali - Karan Mhaswadkar?"})
print(response)
# Out:
# Esports in India has been rapidly growing, with Valorant being one of the prominent titles in the competitive scene. Valorant, developed by Riot Games, is a tactical first-person shooter game that has gained immense popularity worldwide, including in India. The Indian esports community has embraced Valorant due to its thrilling gameplay, strategic depth, and potential for competitive play.
#
# In India, several esports organizations, tournaments, and leagues have emerged, building a vibrant community around Valorant. Many Indian players and teams have gained recognition in regional and international tournaments, helping to boost the profile of esports in the country.
#
# ...
